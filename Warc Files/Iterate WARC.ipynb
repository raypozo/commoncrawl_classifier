# %%
#warcio is used to iterate over warc file
#boilerpipe is used to extract text from HTML pages

from warcio.archiveiterator import ArchiveIterator
import io, time, json
from boilerpipe.extract import Extractor
import datetime
from collections import defaultdict
import numpy as np
from scipy import stats
import json

# %%
#RUN EVERYTHING
a = datetime.datetime.now()
print (a)



with open('warc_commoncrawl_example_2', 'rb') as stream:
    
    #Initialize data structures used to store the parsed webpages 
    data_file = {}
    web_pages = []
    not_parsed_types = defaultdict(int)
    warc_offset=0
    parsed_pages = 0
    not_parsed_pages = 0
    
    #Iterate the .WARC file
    for record in ArchiveIterator(stream):
        
        #there is only one 'warcinfo' per file
        #represents the metadata of that file
        if record.rec_type == 'warcinfo':
            
            #warc_warcinfo header
            tmp = dict(record.rec_headers.headers)
            data_file['date']=tmp['WARC-Date']
            data_file['filename']=tmp['WARC-Filename']
        
        #represents the HTTP response.
        #This represent the crawled data
        elif record.rec_type == 'response':
            
            #warc_response header
            tmp = dict(record.rec_headers.headers)
            record_dict = {'warc_offset':warc_offset,
                        'length':int(tmp['Content-Length']),
                        'ip':tmp['WARC-IP-Address'],
                        'URI':tmp['WARC-Target-URI'],
                        'Payload-Digest': tmp['WARC-Payload-Digest']
                          }
            
            #there are different several types of data,
            #we only parse HTML files and decide that using the HTTP Header field'content-types'
            content_type = record.http_headers.get_header('Content-Type')
            if content_type != None and content_type[:9] == 'text/html':
                
                #Extract text from HTML, no removing of punctuation/numbers. 
                #no lower case conversion,etc. is done
                try:

                    all_crawl = record.raw_stream.read()
                    #print ("**************************************")
                    #print ("WARC offfset", warc_offset)
                    #print(all_crawl, type(all_crawl))
                    
                    #validate if the HTML webpage has content
                    if all_crawl != None and all_crawl != b'':
                        
                        
                        extractor = Extractor(extractor='KeepEverythingExtractor', 
                                            kMin=20, 
                                              html=all_crawl)
                        parsed_text = extractor.getText()
                        if len(parsed_text) > 0:
                            record_dict['text'] = parsed_text
                            web_pages.append(record_dict)
                            parsed_pages +=1
                        else:
                            #parsed data is empty
                            not_parsed_types['ZERO_DATA']+=1
                            not_parsed_pages +=1
                    else:
                        #entire HTML is empty
                        #print ("Couldn't find anything to parse, found None object or empty string")
                        not_parsed_pages +=1
                        not_parsed_types['ZERO_DATA']+=1
                        
                except UnicodeDecodeError:
                    #print ("Boilerpipe chose wrong encode selection, going to skip this")
                    not_parsed_pages+=1
                    not_parsed_types['WRONG_ENCODING'] += 1
                    #record_dict['text'] = None
                    
                except TypeError:
                    #print ("Unkown error appear, going to skip this")
                    not_parsed_pages+=1
                    not_parsed_types['UNKNOWN'] += 1
                    #record_dict['text'] = None
                
                
            else:
                not_parsed_pages +=1
                if content_type:
                    content_type = content_type.lower().split(';')
                    #print("No HTML found, found " + content_type + ". Not parsing")
                    not_parsed_types[content_type[0]] += 1
                else:
                    #print("****************************")
                    #print("Don't know what this HTTP response has:\n/t/t" \
                          +str(record.http_headers))
                    not_parsed_types['WRONG_HTTP_RESPONSE'] += 1
                    #print("****************************")
        
        elif record.rec_type == 'resource':
            print  ("WARC file with type RESOURCE find")
        
        elif record.rec_type == 'revisit':
            print  ("WARC file with type REVISIT find")
        
        elif record.rec_type == 'conversion':
            print  ("WARC file with type CONVERSION find")
        
        warc_offset+=1
        if warc_offset % 500 == 0:
            print ("OFFSET: ",warc_offset," PARSED: ",parsed_pages,
                  "NOT_PARSED: ", not_parsed_pages)

print ("THE END")
print ("Total parsed pages: ",parsed_pages,
                  "\nTotal not parsed: ", not_parsed_pages)
for key,value in not_parsed_types.items():
    print ("\t",key,": ",value)

b = datetime.datetime.now()
print (b)
print (b-a)

###CHECK for the error
# Out:
# 2018-03-02 01:00:45.411298
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Microsoft-IIS/8.0
# p3p: CP=BUS CUR CONo FIN IVDo ONL OUR PHY SAMo TELo
# Date: Fri, 05 Feb 2016 21:55:55 GMT
# Connection: close
# Content-Length: 0
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Microsoft-IIS/8.0
# p3p: CP=BUS CUR CONo FIN IVDo ONL OUR PHY SAMo TELo
# Date: Fri, 05 Feb 2016 22:06:08 GMT
# Connection: close
# Content-Length: 0
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Microsoft-IIS/8.0
# p3p: CP=BUS CUR CONo FIN IVDo ONL OUR PHY SAMo TELo
# Date: Fri, 05 Feb 2016 22:16:30 GMT
# Connection: close
# Content-Length: 0
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  500  PARSED:  150 NOT_PARSED:  14
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.0 200 OK
# Connection: keep-alive
# Expires: Mon, 15 Jun 1998 00:00:00 GMT
# Pragma: no-cache
# Cache-Control: no-store, no-cache
# Content-Length: 1
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  1000  PARSED:  308 NOT_PARSED:  22
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Apache-Coyote/1.1
# Content-Length: 0
# Date: Fri, 05 Feb 2016 22:37:18 GMT
# Connection: close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Apache-Coyote/1.1
# Content-Length: 0
# Date: Fri, 05 Feb 2016 22:30:05 GMT
# Connection: close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Apache-Coyote/1.1
# Content-Length: 0
# Date: Fri, 05 Feb 2016 22:35:06 GMT
# Connection: close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Apache-Coyote/1.1
# Content-Length: 0
# Date: Fri, 05 Feb 2016 22:23:17 GMT
# Connection: close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Apache-Coyote/1.1
# Content-Length: 0
# Date: Fri, 05 Feb 2016 22:23:31 GMT
# Connection: close
#
# ****************************
# OFFSET:  1500  PARSED:  456 NOT_PARSED:  38
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  2000  PARSED:  614 NOT_PARSED:  45
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  2500  PARSED:  769 NOT_PARSED:  57
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  3000  PARSED:  924 NOT_PARSED:  65
# OFFSET:  3500  PARSED:  1082 NOT_PARSED:  70
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  4000  PARSED:  1235 NOT_PARSED:  84
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  4500  PARSED:  1384 NOT_PARSED:  102
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  5000  PARSED:  1533 NOT_PARSED:  113
# OFFSET:  5500  PARSED:  1694 NOT_PARSED:  119
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  6000  PARSED:  1854 NOT_PARSED:  125
# OFFSET:  6500  PARSED:  2012 NOT_PARSED:  133
# OFFSET:  7000  PARSED:  2169 NOT_PARSED:  139
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-control: no-cache="set-cookie"
# Date: Fri, 05 Feb 2016 22:21:07 GMT
# Refresh: 0;URL=http://www.bethesdasoccer.org/Default.aspx?tabid=200237&mid=228230&newskeyid=HN1&newsid=17659&ctl=newsdetail
# Server: Microsoft-IIS/8.5
# Set-Cookie: AWSELB=BB6DB7E11A9C93C914F75969147B8B5F8FD45ED770907DCD7AE0D5C8A3A6829DF6B93E2459D551393DDC0CF70B17AB0772E762E0EBE3C434F53EEEB9C5B4049FFDE2B91A4B;PATH=/
# Content-Length: 237
# Connection: Close
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  7500  PARSED:  2321 NOT_PARSED:  153
# OFFSET:  8000  PARSED:  2485 NOT_PARSED:  154
# OFFSET:  8500  PARSED:  2642 NOT_PARSED:  163
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  9000  PARSED:  2795 NOT_PARSED:  175
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Connection: close
# Date: Fri, 05 Feb 2016 22:16:37 GMT
# Content-Length: 94
# X-Powered-By: Servlet/2.4 JSP/2.0
#
# ****************************
# OFFSET:  9500  PARSED:  2954 NOT_PARSED:  182
# OFFSET:  10000  PARSED:  3115 NOT_PARSED:  184
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  10500  PARSED:  3266 NOT_PARSED:  196
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  11000  PARSED:  3417 NOT_PARSED:  210
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  11500  PARSED:  3570 NOT_PARSED:  222
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  12000  PARSED:  3733 NOT_PARSED:  225
# OFFSET:  12500  PARSED:  3893 NOT_PARSED:  228
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  13000  PARSED:  4036 NOT_PARSED:  248
# OFFSET:  13500  PARSED:  4192 NOT_PARSED:  252
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  14000  PARSED:  4357 NOT_PARSED:  253
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  14500  PARSED:  4521 NOT_PARSED:  254
# OFFSET:  15000  PARSED:  4686 NOT_PARSED:  254
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  15500  PARSED:  4847 NOT_PARSED:  258
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  16000  PARSED:  5000 NOT_PARSED:  269
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  16500  PARSED:  5148 NOT_PARSED:  281
# OFFSET:  17000  PARSED:  5310 NOT_PARSED:  284
# OFFSET:  17500  PARSED:  5475 NOT_PARSED:  286
# OFFSET:  18000  PARSED:  5619 NOT_PARSED:  308
# OFFSET:  18500  PARSED:  5674 NOT_PARSED:  416
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  19000  PARSED:  5836 NOT_PARSED:  421
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  19500  PARSED:  5979 NOT_PARSED:  445
# OFFSET:  20000  PARSED:  6141 NOT_PARSED:  448
# OFFSET:  20500  PARSED:  6303 NOT_PARSED:  451
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  21000  PARSED:  6457 NOT_PARSED:  461
# OFFSET:  21500  PARSED:  6613 NOT_PARSED:  469
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  22000  PARSED:  6771 NOT_PARSED:  474
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  22500  PARSED:  6930 NOT_PARSED:  480
# OFFSET:  23000  PARSED:  7093 NOT_PARSED:  482
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  23500  PARSED:  7247 NOT_PARSED:  490
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  24000  PARSED:  7399 NOT_PARSED:  502
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  24500  PARSED:  7559 NOT_PARSED:  506
# OFFSET:  25000  PARSED:  7715 NOT_PARSED:  512
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  25500  PARSED:  7868 NOT_PARSED:  523
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 22:19:49 GMT
# Server: Apache/2.4.7 (Ubuntu)
# Last-Modified: Wed, 25 Jan 2012 00:00:00 GMT
# ETag: "dd-4b74ef1dd8000"
# Content-Length: 221
# X-Varnish: 43098112
# Age: 0
# Via: 1.1 varnish-v4
# Connection: close
# Accept-Ranges: bytes
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  26000  PARSED:  8028 NOT_PARSED:  528
# OFFSET:  26500  PARSED:  8192 NOT_PARSED:  529
# OFFSET:  27000  PARSED:  8353 NOT_PARSED:  532
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  27500  PARSED:  8484 NOT_PARSED:  567
# OFFSET:  28000  PARSED:  8643 NOT_PARSED:  574
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  28500  PARSED:  8795 NOT_PARSED:  587
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  29000  PARSED:  8953 NOT_PARSED:  594
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  29500  PARSED:  9111 NOT_PARSED:  600
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  30000  PARSED:  9275 NOT_PARSED:  602
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  30500  PARSED:  9423 NOT_PARSED:  615
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 22:09:09 GMT
# Server: Apache
# Set-Cookie: PHPSESSID=72c76c13vc4v96ksnh83b90m50; path=/
# Expires: 0
# Cache-Control: must-revalidate
# Pragma: public
# Content-Description: File Transfer
# Content-Disposition: attachment; filename=cornucopia.pdf
# Content-Transfer-Encoding: binary
# Content-Length: 8700925
# X-Powered-By: PleskLin
# Connection: close
# Content-Type:
#
# ****************************
# OFFSET:  31000  PARSED:  9584 NOT_PARSED:  619
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  31500  PARSED:  9738 NOT_PARSED:  632
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  32000  PARSED:  9879 NOT_PARSED:  657
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  32500  PARSED:  10043 NOT_PARSED:  660
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  33000  PARSED:  10201 NOT_PARSED:  662
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  33500  PARSED:  10356 NOT_PARSED:  672
# OFFSET:  34000  PARSED:  10520 NOT_PARSED:  674
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  34500  PARSED:  10683 NOT_PARSED:  677
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Content-Length: 0
# Set-Cookie: ASP.NET_SessionId=krmr0i2uriftle45qyalin55; path=/; HttpOnly
# Set-Cookie: 8qftoqigzxFjdU9ceaJXskiPsqK4fgv9OpYXbhycj0Q%3d=; path=/
# Set-Cookie: fBAYZs0GqYjDgE9jFPun56%2bixDM3yqmzEw9mkbuuaYc%3d=; path=/
# X-Frame-Options: SAMEORIGIN
# Date: Fri, 05 Feb 2016 23:29:31 GMT
# Connection: close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 23:29:49 GMT
# Server: Microsoft-IIS/7.5
# Set-Cookie: SSLB=1; path=/; domain=.nba.com
# RTSS: 1-1111-9
# X-Powered-By: ASP.NET
# Content-Length: 0
# Set-Cookie: BIGipServerord-s02-CP30-Web1=3HTgCiBBXGnjG8sjMnFbSeiEwoFL5pQyjadYdNlLCo0GEfQanMrtalQGmOZdlUboGuN4ZFy/4QocuojQAcekv4VHQEzzAxXqY+0LupCfBxfIdzok7gQkmCv0RJ6blnsZgA6d6iZt45vJDHPWkJMXT9gW; path=/
# Vary: Accept-Encoding
# Connection: close
# Set-Cookie: BIGipServerord-s02-SS-Pool=643861770.0.0000; path=/
#
# ****************************
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  35000  PARSED:  10842 NOT_PARSED:  681
# Unkown error appear, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  35500  PARSED:  10998 NOT_PARSED:  687
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  36000  PARSED:  11154 NOT_PARSED:  694
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  36500  PARSED:  11314 NOT_PARSED:  698
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Content-Length: 0
# Server: Microsoft-IIS/8.5
# X-AspNet-Version: 4.0.30319
# X-AspNetMvc-Version: 5.2
# Set-Cookie: ASP.NET_SessionId=viroracfgxa4ncb3kqekdfma; path=/; HttpOnly
# X-UA-Compatible: IE=edge
# Date: Fri, 05 Feb 2016 22:07:46 GMT
# Connection: close
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  37000  PARSED:  11474 NOT_PARSED:  705
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  37500  PARSED:  11621 NOT_PARSED:  724
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  38000  PARSED:  11783 NOT_PARSED:  727
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  38500  PARSED:  11945 NOT_PARSED:  729
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  39000  PARSED:  12101 NOT_PARSED:  738
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  39500  PARSED:  12247 NOT_PARSED:  756
# OFFSET:  40000  PARSED:  12409 NOT_PARSED:  759
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  40500  PARSED:  12569 NOT_PARSED:  765
# OFFSET:  41000  PARSED:  12732 NOT_PARSED:  767
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  41500  PARSED:  12877 NOT_PARSED:  773
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  42000  PARSED:  13038 NOT_PARSED:  778
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  42500  PARSED:  13191 NOT_PARSED:  790
# OFFSET:  43000  PARSED:  13351 NOT_PARSED:  791
# OFFSET:  43500  PARSED:  13516 NOT_PARSED:  793
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Server: Microsoft-IIS/7.5
# Set-Cookie: lang=en-US; path=/
# Set-Cookie: langName=English; path=/
# Set-Cookie: langId=4; path=/
# Set-Cookie: ThemeName=EnTheme; path=/
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:12:54 GMT
# Connection: close
# Content-Length: 0
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  44000  PARSED:  13677 NOT_PARSED:  796
# OFFSET:  44500  PARSED:  13837 NOT_PARSED:  799
# OFFSET:  45000  PARSED:  13999 NOT_PARSED:  802
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  45500  PARSED:  14163 NOT_PARSED:  804
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  46000  PARSED:  14323 NOT_PARSED:  805
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Server: Microsoft-IIS/7.5
# X-AspNet-Version: 2.0.50727
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:25:22 GMT
# Connection: close
# Content-Length: 0
# Set-Cookie: SERVERID_VENICE=fHVgQlnyrm4cKykm; path=/
#
# ****************************
# OFFSET:  46500  PARSED:  14483 NOT_PARSED:  810
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.6.3
# Date: Fri, 05 Feb 2016 22:22:30 GMT
# Connection: close
#
# ****************************
# OFFSET:  47000  PARSED:  14643 NOT_PARSED:  813
# OFFSET:  47500  PARSED:  14809 NOT_PARSED:  813
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  48000  PARSED:  14958 NOT_PARSED:  831
# OFFSET:  48500  PARSED:  15113 NOT_PARSED:  834
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  49000  PARSED:  15271 NOT_PARSED:  840
# OFFSET:  49500  PARSED:  15436 NOT_PARSED:  842
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  50000  PARSED:  15597 NOT_PARSED:  847
# OFFSET:  50500  PARSED:  15760 NOT_PARSED:  849
# OFFSET:  51000  PARSED:  15921 NOT_PARSED:  851
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Microsoft-IIS/7.5
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:30:20 GMT
# Connection: close
# Content-Length: 0
#
# ****************************
# Couldn't find anything to parse, found None object or empty string
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 22:56:04 GMT
# Server: Apache
# X-id: i-440b6d9e
# Connection: Close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 23:24:28 GMT
# Server: Apache
# X-id: i-440b6d9e
# Connection: Close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 22:47:31 GMT
# Server: Apache
# X-id: i-440b6d9e
# Connection: Close
#
# ****************************
# OFFSET:  51500  PARSED:  16071 NOT_PARSED:  865
# OFFSET:  52000  PARSED:  16237 NOT_PARSED:  865
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  52500  PARSED:  16399 NOT_PARSED:  869
# OFFSET:  53000  PARSED:  16560 NOT_PARSED:  874
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  53500  PARSED:  16716 NOT_PARSED:  885
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  54000  PARSED:  16856 NOT_PARSED:  886
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  54500  PARSED:  17009 NOT_PARSED:  889
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  55000  PARSED:  17170 NOT_PARSED:  893
# OFFSET:  55500  PARSED:  17330 NOT_PARSED:  900
# OFFSET:  56000  PARSED:  17493 NOT_PARSED:  902
# OFFSET:  56500  PARSED:  17655 NOT_PARSED:  902
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  57000  PARSED:  17815 NOT_PARSED:  905
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  57500  PARSED:  17977 NOT_PARSED:  909
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  58000  PARSED:  18142 NOT_PARSED:  911
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  58500  PARSED:  18297 NOT_PARSED:  916
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  59000  PARSED:  18453 NOT_PARSED:  924
# OFFSET:  59500  PARSED:  18612 NOT_PARSED:  928
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# ETag: "6866-205-443131913a4c0"
# Content-Length: 517
# Last-Modified: Sun, 06 Jan 2008 19:53:31 GMT
# Connection: close
# Server: Apache/2.2.15 (Red Hat)
# Vary: Accept-Encoding
# Date: Fri, 05 Feb 2016 22:29:21 GMT
# Accept-Ranges: bytes
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# ETag: "24c00-437-42857cc8e8280"
# Content-Length: 1079
# Last-Modified: Wed, 31 Jan 2007 15:31:06 GMT
# Connection: close
# Server: Apache/2.2.15 (Red Hat)
# Vary: Accept-Encoding
# Date: Fri, 05 Feb 2016 22:49:15 GMT
# Accept-Ranges: bytes
#
# ****************************
# OFFSET:  60000  PARSED:  18770 NOT_PARSED:  936
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  60500  PARSED:  18923 NOT_PARSED:  939
# OFFSET:  61000  PARSED:  19084 NOT_PARSED:  941
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  61500  PARSED:  19248 NOT_PARSED:  944
# OFFSET:  62000  PARSED:  19396 NOT_PARSED:  949
# OFFSET:  62500  PARSED:  19562 NOT_PARSED:  950
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  63000  PARSED:  19724 NOT_PARSED:  955
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  63500  PARSED:  19884 NOT_PARSED:  960
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  64000  PARSED:  20043 NOT_PARSED:  965
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  64500  PARSED:  20204 NOT_PARSED:  970
# OFFSET:  65000  PARSED:  20367 NOT_PARSED:  972
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  65500  PARSED:  20533 NOT_PARSED:  973
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  66000  PARSED:  20696 NOT_PARSED:  976
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  66500  PARSED:  20855 NOT_PARSED:  979
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 22:26:53 GMT
# Server: Apache/2.2.22 (Debian)
# Last-Modified: Wed, 19 Nov 2014 02:58:18 GMT
# ETag: "2621008-3fee-5082d6242f8cb"
# Accept-Ranges: bytes
# Content-Length: 16366
# Connection: close
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 22:29:46 GMT
# Server: Apache/2.2.22 (Debian)
# Last-Modified: Sun, 19 Oct 2014 12:21:23 GMT
# ETag: "4e1838-366a-505c5a2e276c0"
# Accept-Ranges: bytes
# Content-Length: 13930
# Connection: close
#
# ****************************
# OFFSET:  67000  PARSED:  21010 NOT_PARSED:  985
# OFFSET:  67500  PARSED:  21164 NOT_PARSED:  991
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  68000  PARSED:  21327 NOT_PARSED:  994
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  68500  PARSED:  21490 NOT_PARSED:  997
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  69000  PARSED:  21653 NOT_PARSED:  999
# OFFSET:  69500  PARSED:  21817 NOT_PARSED:  999
# OFFSET:  70000  PARSED:  21978 NOT_PARSED:  1000
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  70500  PARSED:  22142 NOT_PARSED:  1003
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  71000  PARSED:  22300 NOT_PARSED:  1007
# OFFSET:  71500  PARSED:  22465 NOT_PARSED:  1009
# OFFSET:  72000  PARSED:  22627 NOT_PARSED:  1009
# OFFSET:  72500  PARSED:  22784 NOT_PARSED:  1013
# OFFSET:  73000  PARSED:  22947 NOT_PARSED:  1014
# OFFSET:  73500  PARSED:  23104 NOT_PARSED:  1014
# OFFSET:  74000  PARSED:  23270 NOT_PARSED:  1014
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.0 200 OK
# Server: Microsoft-IIS/7.5
# X-Powered-By: ASP.NET
# GsWebServer2: V-VWC2PGLSWB01
# Content-Length: 0
# Date: Fri, 05 Feb 2016 22:30:40 GMT
# Connection: close
# Set-Cookie: BIGipServerpool-www-prd.globalspec.com-80=rd1100o00000000000000000000ffff0af00030o80;domain=.globalspec.com; path=/
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  74500  PARSED:  23426 NOT_PARSED:  1018
# OFFSET:  75000  PARSED:  23586 NOT_PARSED:  1023
# OFFSET:  75500  PARSED:  23751 NOT_PARSED:  1024
# OFFSET:  76000  PARSED:  23906 NOT_PARSED:  1032
# OFFSET:  76500  PARSED:  24066 NOT_PARSED:  1035
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  77000  PARSED:  24225 NOT_PARSED:  1040
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  77500  PARSED:  24388 NOT_PARSED:  1044
# OFFSET:  78000  PARSED:  24544 NOT_PARSED:  1055
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  78500  PARSED:  24699 NOT_PARSED:  1057
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  79000  PARSED:  24863 NOT_PARSED:  1058
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  79500  PARSED:  25020 NOT_PARSED:  1064
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 23:03:05 GMT
# Server: Apache
# Last-Modified: Fri, 28 Aug 2009 07:25:51 GMT
# ETag: "15c9c-4722e9803bebd"
# Accept-Ranges: bytes
# Content-Length: 89244
# Connection: close
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  80000  PARSED:  25177 NOT_PARSED:  1072
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  80500  PARSED:  25343 NOT_PARSED:  1073
# OFFSET:  81000  PARSED:  25506 NOT_PARSED:  1075
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  81500  PARSED:  25667 NOT_PARSED:  1079
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  82000  PARSED:  25827 NOT_PARSED:  1083
# OFFSET:  82500  PARSED:  25985 NOT_PARSED:  1086
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  83000  PARSED:  26146 NOT_PARSED:  1088
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  83500  PARSED:  26309 NOT_PARSED:  1091
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  84000  PARSED:  26468 NOT_PARSED:  1096
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Microsoft-IIS/7.5
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:17:58 GMT
# Connection: close
# Content-Length: 0
#
# ****************************
# OFFSET:  84500  PARSED:  26628 NOT_PARSED:  1102
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  85000  PARSED:  26789 NOT_PARSED:  1106
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  85500  PARSED:  26947 NOT_PARSED:  1112
# OFFSET:  86000  PARSED:  27112 NOT_PARSED:  1112
# OFFSET:  86500  PARSED:  27277 NOT_PARSED:  1114
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  87000  PARSED:  27437 NOT_PARSED:  1119
# OFFSET:  87500  PARSED:  27601 NOT_PARSED:  1121
# Boilerpipe chose wrong encode selection, going to skip this
# Unkown error appear, going to skip this
# OFFSET:  88000  PARSED:  27763 NOT_PARSED:  1124
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  88500  PARSED:  27919 NOT_PARSED:  1132
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  89000  PARSED:  28080 NOT_PARSED:  1137
# OFFSET:  89500  PARSED:  28238 NOT_PARSED:  1139
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  90000  PARSED:  28403 NOT_PARSED:  1141
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  90500  PARSED:  28550 NOT_PARSED:  1160
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx
# Date: Fri, 05 Feb 2016 22:33:52 GMT
# Connection: close
# Set-Cookie: X-Mapping-fjhppofk=4484CC9C6693D6BA2A79D00D87AA5D5A; path=/
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Connection: close
# Date: Fri, 05 Feb 2016 22:08:36 GMT
# Content-Length: 94
# X-Powered-By: Servlet/2.4 JSP/2.0
#
# ****************************
# OFFSET:  91000  PARSED:  28712 NOT_PARSED:  1165
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  91500  PARSED:  28876 NOT_PARSED:  1166
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  92000  PARSED:  29037 NOT_PARSED:  1169
# OFFSET:  92500  PARSED:  29201 NOT_PARSED:  1171
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  93000  PARSED:  29347 NOT_PARSED:  1179
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  93500  PARSED:  29505 NOT_PARSED:  1187
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Server: Microsoft-IIS/7.5
# X-AspNet-Version: 2.0.50727
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:26:57 GMT
# Connection: close
# Content-Length: 0
# Set-Cookie: SERVERID_VENICE=fHVgQlnyrm4cKykm; path=/
#
# ****************************
# OFFSET:  94000  PARSED:  29669 NOT_PARSED:  1188
# OFFSET:  94500  PARSED:  29832 NOT_PARSED:  1190
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 22:10:20 GMT
# Server: Apache/2.4.7 (Ubuntu)
# Last-Modified: Wed, 25 Jan 2012 00:00:00 GMT
# ETag: "150-4b74ef1dd8000"
# Content-Length: 336
# X-Varnish: 42554137
# Age: 0
# Via: 1.1 varnish-v4
# Connection: close
# Accept-Ranges: bytes
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Date: Fri, 05 Feb 2016 23:04:17 GMT
# Server: Apache/2.4.7 (Ubuntu)
# Last-Modified: Mon, 28 Jan 2013 00:00:00 GMT
# ETag: "528-4d44df54ee000"
# Content-Length: 1320
# X-Varnish: 43221008
# Age: 0
# Via: 1.1 varnish-v4
# Connection: close
# Accept-Ranges: bytes
#
# ****************************
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  95000  PARSED:  29983 NOT_PARSED:  1198
# OFFSET:  95500  PARSED:  30140 NOT_PARSED:  1204
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  96000  PARSED:  30299 NOT_PARSED:  1210
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  96500  PARSED:  30455 NOT_PARSED:  1215
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  97000  PARSED:  30614 NOT_PARSED:  1222
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  97500  PARSED:  30775 NOT_PARSED:  1226
# OFFSET:  98000  PARSED:  30937 NOT_PARSED:  1229
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  98500  PARSED:  31090 NOT_PARSED:  1237
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  99000  PARSED:  31251 NOT_PARSED:  1243
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  99500  PARSED:  31413 NOT_PARSED:  1247
# OFFSET:  100000  PARSED:  31572 NOT_PARSED:  1249
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  100500  PARSED:  31734 NOT_PARSED:  1251
# OFFSET:  101000  PARSED:  31893 NOT_PARSED:  1255
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  101500  PARSED:  32048 NOT_PARSED:  1267
# Unkown error appear, going to skip this
# Unkown error appear, going to skip this
# OFFSET:  102000  PARSED:  32209 NOT_PARSED:  1273
# OFFSET:  102500  PARSED:  32374 NOT_PARSED:  1274
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  103000  PARSED:  32528 NOT_PARSED:  1281
# OFFSET:  103500  PARSED:  32692 NOT_PARSED:  1284
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Microsoft-IIS/8.5
# Date: Fri, 05 Feb 2016 23:13:26 GMT
# Connection: close
# Content-Length: 0
# Set-Cookie: BIGipServercgis_pol_web_pool-http=!aEpfG77DZSun8DjVVZwnwxKzRjoc1ROXwibbO31gu3OfpXiipun4egVfononiIr7olhwG3zjikvd738=; path=/
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: Microsoft-IIS/8.5
# Date: Fri, 05 Feb 2016 22:20:04 GMT
# Connection: close
# Content-Length: 0
# Set-Cookie: BIGipServercgis_pol_web_pool-http=!7xwQ7DNJZ3PJvW7VVZwnwxKzRjoc1bC2MYgE7XWDqX2JbKsTLE0Bd2XFhmG7o9OeTQaZwmE5nuyX9TA=; path=/
#
# ****************************
# OFFSET:  104000  PARSED:  32849 NOT_PARSED:  1290
# OFFSET:  104500  PARSED:  33014 NOT_PARSED:  1292
# OFFSET:  105000  PARSED:  33176 NOT_PARSED:  1297
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  105500  PARSED:  33317 NOT_PARSED:  1301
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  106000  PARSED:  33480 NOT_PARSED:  1304
# OFFSET:  106500  PARSED:  33643 NOT_PARSED:  1306
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  107000  PARSED:  33803 NOT_PARSED:  1312
# OFFSET:  107500  PARSED:  33969 NOT_PARSED:  1313
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Server: Microsoft-IIS/7.5
# X-AspNet-Version: 2.0.50727
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:39:26 GMT
# Connection: close
# Content-Length: 0
# Set-Cookie: SERVERID_VENICE=9I6N3X6DAKE7m3qa; path=/
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Server: Microsoft-IIS/7.5
# X-AspNet-Version: 2.0.50727
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:41:29 GMT
# Connection: close
# Content-Length: 0
# Set-Cookie: SERVERID_VENICE=fHVgQlnyrm4cKykm; path=/
#
# ****************************
# OFFSET:  108000  PARSED:  34121 NOT_PARSED:  1325
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.0 200 OK
# Server: Apache
# Last-Modified: Fri, 05 Feb 2016 22:51:26 GMT
# ETag: W/"d13c-52b0db0e7a89d"
# Accept-Ranges: bytes
# Content-Length: 53564
# Cache-Control: proxy-revalidate, max-age=604800
# Expires: Fri, 12 Feb 2016 22:51:21 GMT
# X-UA-Compatible: IE=Edge,chrome=1
# Date: Fri, 05 Feb 2016 22:51:26 GMT
# Connection: close
# Set-Cookie: rlx-language=es; expires=Sat, 04-Feb-2017 22:51:26 GMT; path=/; domain=.rolex.com
# Set-Cookie: rlx-language=es; expires=Wed, 22-Aug-2001 17:30:00 GMT; path=/
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.0 200 OK
# Server: Apache
# Last-Modified: Fri, 05 Feb 2016 22:35:10 GMT
# ETag: W/"ceb8-52b0d76c734fa"
# Accept-Ranges: bytes
# Content-Length: 52920
# Cache-Control: proxy-revalidate, max-age=604800
# Expires: Fri, 12 Feb 2016 22:35:09 GMT
# X-UA-Compatible: IE=Edge,chrome=1
# Date: Fri, 05 Feb 2016 22:35:10 GMT
# Connection: close
# Set-Cookie: rlx-language=ja; expires=Sat, 04-Feb-2017 22:35:10 GMT; path=/; domain=.rolex.com
# Set-Cookie: rlx-language=ja; expires=Wed, 22-Aug-2001 17:30:00 GMT; path=/
#
# ****************************
# Boilerpipe chose wrong encode selection, going to skip this
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Content-Length: 0
# Server: Microsoft-IIS/8.0
# X-AspNet-Version: 2.0.50727
# Set-Cookie: ASP.NET_SessionId=yv3s3c45sitk4zjhthnqfl45; path=/; HttpOnly
# Set-Cookie: dJDwrparND33PaWe7K%2fO%2fUlwueEg1ZhYEt1%2fmMjki5w%3d=; path=/
# Set-Cookie: KzCZyq2mHRdqSjDAZZR0GBQs7AVkx5F%2bhxpURmDcyDE%3d=; path=/
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:41:21 GMT
# Connection: close
#
# ****************************
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  108500  PARSED:  34279 NOT_PARSED:  1332
# OFFSET:  109000  PARSED:  34438 NOT_PARSED:  1339
# OFFSET:  109500  PARSED:  34603 NOT_PARSED:  1339
# OFFSET:  110000  PARSED:  34767 NOT_PARSED:  1340
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  110500  PARSED:  34928 NOT_PARSED:  1345
# OFFSET:  111000  PARSED:  35088 NOT_PARSED:  1347
# OFFSET:  111500  PARSED:  35252 NOT_PARSED:  1348
# OFFSET:  112000  PARSED:  35419 NOT_PARSED:  1348
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  112500  PARSED:  35581 NOT_PARSED:  1352
# OFFSET:  113000  PARSED:  35745 NOT_PARSED:  1353
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  113500  PARSED:  35907 NOT_PARSED:  1355
# OFFSET:  114000  PARSED:  36056 NOT_PARSED:  1359
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  114500  PARSED:  36217 NOT_PARSED:  1362
# OFFSET:  115000  PARSED:  36382 NOT_PARSED:  1364
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  115500  PARSED:  36545 NOT_PARSED:  1365
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  116000  PARSED:  36703 NOT_PARSED:  1368
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  116500  PARSED:  36864 NOT_PARSED:  1370
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  117000  PARSED:  37027 NOT_PARSED:  1374
# OFFSET:  117500  PARSED:  37191 NOT_PARSED:  1374
# Couldn't find anything to parse, found None object or empty string
# Unkown error appear, going to skip this
# Unkown error appear, going to skip this
# OFFSET:  118000  PARSED:  37353 NOT_PARSED:  1378
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  118500  PARSED:  37508 NOT_PARSED:  1388
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  119000  PARSED:  37665 NOT_PARSED:  1397
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  119500  PARSED:  37826 NOT_PARSED:  1399
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  120000  PARSED:  37984 NOT_PARSED:  1403
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  120500  PARSED:  38139 NOT_PARSED:  1410
# OFFSET:  121000  PARSED:  38305 NOT_PARSED:  1411
# OFFSET:  121500  PARSED:  38459 NOT_PARSED:  1413
# OFFSET:  122000  PARSED:  38624 NOT_PARSED:  1414
# OFFSET:  122500  PARSED:  38789 NOT_PARSED:  1416
# OFFSET:  123000  PARSED:  38950 NOT_PARSED:  1419
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  123500  PARSED:  39111 NOT_PARSED:  1421
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  124000  PARSED:  39273 NOT_PARSED:  1423
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: "no-cache"
# Cache-control: no-cache="set-cookie"
# Content-Disposition: filename=2009 Emrick Blvd Crit.pdf
# Content-Type:
# Date: Fri, 05 Feb 2016 23:08:17 GMT
# Expires: Thu, 19 Nov 1981 08:52:00 GMT
# Pragma: "no-cache"
# Server: Apache/2.2.29 (Amazon)
# Set-Cookie: PHPSESSID=8v16v6a9u5ahhlokoh48le3ps3; path=/; HttpOnly
# Set-Cookie: AWSELB=8BF723B1048FF6DB8AD1C334A35B5B2D3A8AEC9BC0BE939C9BD91B05A15275A77CAF0C41F9D4E4550BA9AC64BE3D79C8BB7FAED599C5604917971AD8CCE89EA52A2D8006A9;PATH=/;MAX-AGE=3600
# Content-Length: 0
# Connection: Close
#
# ****************************
# OFFSET:  124500  PARSED:  39431 NOT_PARSED:  1431
# OFFSET:  125000  PARSED:  39595 NOT_PARSED:  1431
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  125500  PARSED:  39759 NOT_PARSED:  1434
# OFFSET:  126000  PARSED:  39908 NOT_PARSED:  1442
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  126500  PARSED:  40067 NOT_PARSED:  1448
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  127000  PARSED:  40229 NOT_PARSED:  1453
# OFFSET:  127500  PARSED:  40390 NOT_PARSED:  1454
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  128000  PARSED:  40537 NOT_PARSED:  1455
# OFFSET:  128500  PARSED:  40703 NOT_PARSED:  1455
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  129000  PARSED:  40864 NOT_PARSED:  1460
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  129500  PARSED:  41015 NOT_PARSED:  1474
# OFFSET:  130000  PARSED:  41179 NOT_PARSED:  1477
# OFFSET:  130500  PARSED:  41339 NOT_PARSED:  1477
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  131000  PARSED:  41487 NOT_PARSED:  1480
# OFFSET:  131500  PARSED:  41650 NOT_PARSED:  1483
# OFFSET:  132000  PARSED:  41805 NOT_PARSED:  1489
# OFFSET:  132500  PARSED:  41962 NOT_PARSED:  1489
# OFFSET:  133000  PARSED:  42126 NOT_PARSED:  1492
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  133500  PARSED:  42286 NOT_PARSED:  1498
# OFFSET:  134000  PARSED:  42448 NOT_PARSED:  1500
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  134500  PARSED:  42607 NOT_PARSED:  1504
# OFFSET:  135000  PARSED:  42773 NOT_PARSED:  1505
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  135500  PARSED:  42937 NOT_PARSED:  1507
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  136000  PARSED:  43100 NOT_PARSED:  1510
# Boilerpipe chose wrong encode selection, going to skip this
# Couldn't find anything to parse, found None object or empty string
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  136500  PARSED:  43251 NOT_PARSED:  1526
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  137000  PARSED:  43414 NOT_PARSED:  1528
# OFFSET:  137500  PARSED:  43579 NOT_PARSED:  1530
# OFFSET:  138000  PARSED:  43742 NOT_PARSED:  1531
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  138500  PARSED:  43903 NOT_PARSED:  1536
# OFFSET:  139000  PARSED:  44068 NOT_PARSED:  1537
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  139500  PARSED:  44223 NOT_PARSED:  1547
# OFFSET:  140000  PARSED:  44387 NOT_PARSED:  1547
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  140500  PARSED:  44547 NOT_PARSED:  1550
# OFFSET:  141000  PARSED:  44712 NOT_PARSED:  1550
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  141500  PARSED:  44868 NOT_PARSED:  1558
# OFFSET:  142000  PARSED:  45033 NOT_PARSED:  1559
# Couldn't find anything to parse, found None object or empty string
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 23:44:41 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 23:01:06 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 23:20:38 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 22:49:29 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 23:28:51 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 22:23:01 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 23:11:22 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 23:21:26 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 22:36:22 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Server: nginx/1.9.2
# Date: Fri, 05 Feb 2016 23:20:16 GMT
# Connection: close
# X-Powered-By: Express
# Front-End-Https: on
#
# ****************************
# ****************************
# Don't know what this HTTP response has:
# /t/tHTTP/1.1 200 OK
# Cache-Control: private
# Content-Length: 0
# Server: Microsoft-IIS/7.5
# X-AspNet-Version: 2.0.50727
# X-Powered-By: ASP.NET
# Date: Fri, 05 Feb 2016 22:28:17 GMT
# Connection: close
#
# ****************************
# OFFSET:  142500  PARSED:  45186 NOT_PARSED:  1571
# OFFSET:  143000  PARSED:  45342 NOT_PARSED:  1575
# OFFSET:  143500  PARSED:  45496 NOT_PARSED:  1577
# OFFSET:  144000  PARSED:  45660 NOT_PARSED:  1578
# OFFSET:  144500  PARSED:  45820 NOT_PARSED:  1580
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  145000  PARSED:  45982 NOT_PARSED:  1584
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  145500  PARSED:  46137 NOT_PARSED:  1589
# OFFSET:  146000  PARSED:  46299 NOT_PARSED:  1590
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  146500  PARSED:  46452 NOT_PARSED:  1601
# OFFSET:  147000  PARSED:  46611 NOT_PARSED:  1605
# Boilerpipe chose wrong encode selection, going to skip this
# OFFSET:  147500  PARSED:  46774 NOT_PARSED:  1608
# OFFSET:  148000  PARSED:  46941 NOT_PARSED:  1608
# Couldn't find anything to parse, found None object or empty string
# Couldn't find anything to parse, found None object or empty string
# OFFSET:  148500  PARSED:  47105 NOT_PARSED:  1611
# OFFSET:  149000  PARSED:  47269 NOT_PARSED:  1611
# THE END
# Total parsed pages:  47374
# Total not parsed:  1612
# 	 WRONG_ENCODING :  282
# 	 image/jpeg :  214
# 	 application/atom+xml; charset=utf-8 :  52
# 	 text/xml; charset=utf-8 :  86
# 	 text/plain :  61
# 	 application/rdf+xml :  2
# 	 application/rss+xml; charset=utf-8 :  135
# 	 image/gif :  21
# 	 application/vnd.google-earth.kml+xml; charset=utf-8 :  1
# 	 application/xml :  17
# 	 text/xml :  26
# 	 application/vnd.ms-excel :  3
# 	 application/x-httpd-php :  1
# 	 application/pdf :  60
# 	 application/atom+xml :  11
# 	 text/calendar; charset=utf-8 :  13
# 	 application/pdf; charset=utf-8 :  7
# 	 application/rss+xml :  12
# 	 application/xml; charset=utf-8 :  17
# 	 image/jpg :  5
# 	 text/plain;charset=iso-8859-1 :  1
# 	 image/jpeg;charset=utf-8 :  5
# 	 text/html; charset=utf-8 :  11
# 	 image/jp2 :  1
# 	 text/plain; charset=utf-8 :  26
# 	 text/xml;charset=utf-8 :  13
# 	 text/xml; charset=us-ascii :  1
# 	 application/octet-stream :  32
# 	 application/octet-stream;charset=utf-8 :  1
# 	 image/vnd.djvu :  1
# 	 application/x-tar :  1
# 	 application/xhtml+xml;charset=utf-8 :  4
# 	 image/png :  119
# 	 application/text; charset=utf-8 :  1
# 	 applications/x-research-info-systems :  1
# 	 text/plain;charset=utf-8 :  1
# 	 application/rss+xml; :  1
# 	 application/vnd.google-earth.kml+xml :  2
# 	 application/xhtml+xml; charset=utf-8 :  14
# 	 text/xml; charset=iso-8859-1 :  1
# 	 video/webm :  1
# 	 application/x-md5 :  1
# 	 application/msword :  4
# 	 audio/mpeg :  2
# 	 application/xhtml+xml :  1
# 	 text/x-patch :  1
# 	 application/rss+xml;charset=utf-8 :  3
# 	 application/x-zip-compressed :  1
# 	 UNKNOWN :  6
# 	 application/octetstream :  1
# 	 text/plain; charset=iso-8859-1 :  8
# 	 audio/x-scpls :  1
# 	 application/msword;charset=utf-8 :  1
# 	 image/jpeg; charset=utf-8 :  2
# 	 application/x-research-info-systems :  1
# 	 audio/midi :  1
# 	 text/calendar :  3
# 	 application/rss+xml; charset="utf-8" :  1
# 	 text/calendar; name=icalendar.ics :  8
# 	 lot :  4
# 	 application/force-download :  2
# 	 text/xml;  charset=utf-8 :  1
# 	 text/xml; charset="utf-8" :  1
# 	 application/rdf+xml; charset=utf-8 :  1
# 	 audio/x-mpegurl :  1
# 	 application/json :  6
# 	 application/json; charset=utf-8 :  10
# 	 application/octet-stream; charset=utf-8 :  2
# 	 video/x-ms-asf :  5
# 	 text/csv;charset=utf-8 :  1
# 	 application/xml;charset=iso-8859-1 :  1
# 	 application/atom+xml;charset=iso-8859-1 :  2
# 	 application/pdf;charset=utf-8 :  3
# 	 unknown/unknown :  2
# 	 text/x-lilypond :  1
# 	 audio/x-wav :  7
# 	 image/pjpeg :  2
# 	 application/dxf :  1
# 	 application/vnd.wap.xhtml+xml; charset=utf-8 :  2
# 	 jpg :  1
# 	 text/x-dsrc :  2
# 	 text/x-fortran :  1
# 	 text/calendar;charset=utf-8 :  3
# 	 application/vnd.google-earth.kmz :  2
# 	 text/plain; charset=iso-8859-1; :  1
# 	 text/xml; charset=windows-1252 :  1
# 	 application/vnd.ms-excel;charset=utf-8 :  1
# 	 message/rfc822 :  1
# 	 binary/octet-stream :  1
# 	 unknown mime type :  1
# 	 text/xml; charset=windows-1250 :  1
# 	 text/html; charset=windows-1254 :  1
# 	 text/x-vcalendar :  1
# 	 application/download;;charset=utf-8 :  2
# 	 application/vnd.ms-powerpoint :  1
# 	 text/html :  1
# 	 audio/x-scpls;charset=iso-8859-1 :  2
# 	 text/x-diff; charset=utf-8 :  1
# 	 application/zip :  2
# 	 text/tab-separated-values;charset=utf-8 :  1
# 	 application/octet-stream;charset=iso-8859-1 :  1
# 	 application/x-shockwave-flash :  1
# 2018-03-02 05:58:18.291764
# 4:57:32.880466

# %%
#Get stats
print("Total number of parsed files: ",len(web_pages))
len_text = []
for x in web_pages:
    len_text.append(len(x['text']))
a = np.asarray(len_text)
stats.describe(a)
# Out:
# Total number of parsed files:  47374
# DescribeResult(nobs=47374, minmax=(2, 997491), mean=6232.388293156584, variance=165824154.05565083, skewness=26.430153979182524, kurtosis=1367.6593689238523)

# %%
#write it down to a file

json_text = json.dumps(web_pages)
with open("parsed_data2.txt",'w') as file:
    json.dump(json_text, file)

# %%
a = "image/jpeg" 
c = "application/atom+xml; charset=utf-8"
c.split(';')
# Out:
# ['application/atom+xml', ' charset=utf-8']
